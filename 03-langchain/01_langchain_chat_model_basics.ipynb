# %% [markdown]
# <a href="https://colab.research.google.com/github/RAJAMURUGAN-VS/genai-learning-journey/blob/main/03-langchain/01_langchain_chat_model_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 3.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
from langchain.chat_models import init_chat_model

# %%
api_key=userdata.get('GEMINI_API_KEY')

# %%
model=init_chat_model(
    "google_genai:gemini-2.5-flash",
    api_key=api_key
)

# %%
response=model.invoke("What are AI agents")

# %%
print(response.content)
# Out:
# AI agents are a type of artificial intelligence system designed to **perceive their environment, make decisions, and take actions autonomously to achieve specific goals.**
#
# Think of them as a more sophisticated, proactive version of traditional AI tools. While a regular AI model (like an image classifier or a language model) performs a specific task when prompted, an AI agent orchestrates multiple such tasks, often interacting with various tools and systems, to complete a larger, multi-step objective without constant human intervention.
#
# Here's a breakdown of their core components and characteristics:
#
# 1.  **Perception:** They gather information from their environment. This can involve:
#     *   Reading text (e.g., emails, documents, web pages)
#     *   Analyzing data (e.g., spreadsheets, databases)
#     *   Monitoring real-world sensors (e.g., cameras, microphones, IoT devices)
#     *   Interacting with APIs (Application Programming Interfaces)
#
# ...
