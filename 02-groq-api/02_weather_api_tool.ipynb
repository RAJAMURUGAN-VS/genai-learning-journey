# %% [markdown]
# <a href="https://colab.research.google.com/github/RAJAMURUGAN-VS/genai-learning-journey/blob/main/02-groq-api/02_weather_api_tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Groq package

# %%
# !pip install groq

# %% [markdown]
# Import necessary classes and functions

# %%
from google.colab import userdata
from groq import Groq
from pprint import pprint
import json
import requests

# %% [markdown]
# Create client object using Groq class

# %%
client=Groq(
  api_key=userdata.get('GROQ_API_KEY')
)
print(client)

# %% [markdown]
# Function to get Weather Information

# %%
def get_weather(location):
 api_key = userdata.get('WEATHER_API_KEY')
 url = f"http://api.openweathermap.org/data/2.5/weather?q={location}&units=metric&appid={api_key}"
 response = requests.get(url)
 data = response.json()
 pprint(data)

 if data["cod"] == 200:
   return {
     "location": location,
     "temperature": data["main"]["temp"],
     "description": data["weather"][0]["description"]
   }
 else:
   return {"Oops! Something went wrong."}

# %% [markdown]
# Example usage

# %%
weather_info = get_weather("Mumbai")
print(weather_info)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 19.0144, 'lon': 72.8479},
#  'dt': 1779769879,
#  'id': 1275339,
#  'main': {'feels_like': 39.99,
#           'grnd_level': 1010,
#           'humidity': 62,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 32.99,
#           'temp_max': 32.99,
#           'temp_min': 31.94},
#  'name': 'Mumbai',
#  'sys': {'country': 'IN',
#          'id': 9052,
#          'sunrise': 1779755487,
#          'sunset': 1779802807,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 5000,
#  'weather': [{'description': 'haze', 'icon': '50d', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 260, 'speed': 3.6}}
# {'location': 'Mumbai', 'temperature': 32.99, 'description': 'haze'}
